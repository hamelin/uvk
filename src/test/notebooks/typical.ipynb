# %%
# /// script
# requires-python = ">=3.13"
# dependencies = [
#     "lark>=1.3.1",
#     "requests>=2.33.1",
# ]
# ///

# %%
import requests
import subprocess as sp

# %%
install_script = requests.get("https://astral.sh/uv/install.sh")
sp.run(["/bin/sh"], input=install_script, encoding="utf-8")
