# %% [markdown]
# This is fine metadata, but it's not a code cell. 🤷

# %% [raw]
# # /// script
# # requires-python = ">=3.13"
# # dependencies = [
# #     "lark>=1.3.1",
# #     "requests>=2.33.1",
# # ]
# #
# # [tool.uvk}
# # uv_args = ["--with-editable", "../my-package"]
# # ///
