# %% [markdown]
# This one's top has an illegal line, so it will trigger an error.

# %%
# /// script
# requires-python = ">=3.13"
# dependencies = [
#     "lark>=1.3.1",
#     "requests>=2.33.1",
# ]

# [tool.uvk]
# uv_args = ["--with-editable", "../my-package"]
# ///

# %% [markdown]
# This perfectly valid metadata snipped is ignored.

# %%
# /// script
# dependencies = [
#     "requests>=2.33.1",
# ]
#
# ///
