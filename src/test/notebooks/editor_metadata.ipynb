# %%
from pathlib import Path
from tempfile import NamedTemporaryFile

# %%
with NamedTemporaryFile(suffix=".py") as script:
    # %uv init --script {script.name}
    # %uv add --script {script.name} requests lark
    get_ipython().set_next_input(Path(script.name).read_text("utf-8").strip())  # type: ignore
# Out:
# Initialized script at `/var/folders/_d/_wb1kbsj2vnccf4sqkcf2zxh0000gn/T/tmpatg7s1nk.py`
# Note: you may need to restart the kernel to use updated packages.
# ...
# Resolved 6 packages in 73ms
# Note: you may need to restart the kernel to use updated packages.

# %%
# /// script
# requires-python = ">=3.13"
# dependencies = [
#     "lark>=1.3.1",
#     "requests>=2.33.1",
# ]
# ///

# %%
# /// script
# requires-python = ">=3.13"
# dependencies = []
# ///
