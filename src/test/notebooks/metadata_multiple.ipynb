# %%
# Not metadata

# %% [markdown]
# This next cell will be it

# %%
# This is the metadata.
# /// script
# requires-python = ">=3.11"
# dependencies = []
# ///

# %% [markdown]
# But we messed up and think this next cell is the metadata. DOH

# %%
# /// script
# requires-python = ">=3.13"
# dependencies = [
#     "lark>=1.3.1",
#     "requests>=2.33.1",
# ]
#
# [tool.uvk]
# uv_args = ["--with-editable", "../my-package"]
# ///
