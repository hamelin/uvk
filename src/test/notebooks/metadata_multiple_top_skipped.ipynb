# %% [markdown]
# This one's top has a broken header, so it will be just skipped.

# %%
# // script
# requires-python = ">=3.13"
# dependencies = [
#     "lark>=1.3.1",
#     "requests>=2.33.1",
# ]
#
# [tool.uvk]
# uv_args = ["--with-editable", "../my-package"]
# ///

# %% [markdown]
# This one is fine, and thus becomes our metadata.

# %%
# /// script
# dependencies = [
#     "requests>=2.33.1",
# ]
#
# ///
